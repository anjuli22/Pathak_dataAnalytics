# %% [markdown]
# importing all necessity packages

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# Importing file data and visualisation

# %%
data_v1=pd.read_csv('BHARTIARTL.csv')
data_v1.head()
# Out:
#              _id            sid  scriptname  scriptcode        value  sign  \
# 0  1613706304101  1613706304101  BHARTIARTL       10604  28774890.00     1
# 1  1613706307619  1613706307619  BHARTIARTL       10604  37438038.00     1
# 2  1613706307683  1613706307683  BHARTIARTL       10604  40689257.95     1
# 3  1613706311944  1613706311944  BHARTIARTL       10604  45336491.75    -1
# 4  1613706311974  1613706311974  BHARTIARTL       10604  57642206.97    -1
#
#    net_count  perc    high     low  ...  cfl916_maxd30_fl916  \
# 0          0   0.3  590.75  590.00  ...                  NaN
# 1          0   0.3  590.85  590.00  ...                  0.0
# 2          0   0.3  590.85  590.00  ...                  0.0
# 3          0   0.2  590.85  590.00  ...                  0.0
# 4          0   0.0  590.85  589.25  ...                  0.0
#
#       change_mind30ltp_time cfl916_mind30_fl916     change_maxs30ltp_time  \
# 0                       NaN                 NaN                       NaN
# 1  2021-02-19T09:15:10.445Z                 0.0  2021-02-19T09:15:10.445Z
# 2  2021-02-19T09:15:10.445Z                 0.0  2021-02-19T09:15:10.445Z
# 3  2021-02-19T09:15:12.271Z                 0.0  2021-02-19T09:15:12.271Z
# 4  2021-02-19T09:15:13.083Z                 0.0  2021-02-19T09:15:13.083Z
#
#    cfl916_maxs30_fl916     change_mins30ltp_time  cfl916_mins30_fl916  \
# 0                  NaN                       NaN                  NaN
# 1                  0.0  2021-02-19T09:15:10.445Z                  0.0
# 2                  0.0  2021-02-19T09:15:10.445Z                  0.0
# 3                  0.0  2021-02-19T09:15:10.445Z                  0.0
# 4                  0.0  2021-02-19T09:15:10.445Z                  0.0
#
#    level_position_flag  d30s30levelindex  change_flag_time
# 0                    1                 1               NaN
# 1                    1                 1               NaN
# 2                    1                 1               NaN
# 3                    4                 4               NaN
# 4                    4                 4               NaN
#
# [5 rows x 157 columns]

# %%
#taking only valuable columns for first regression

data_v2= data_v1.filter(['updatetime','high','low','perc'], axis=1)
data_v2.head()
# Out:
#                  updatetime    high     low  perc
# 0  2021-02-19T09:15:07.457Z  590.75  590.00   0.3
# 1  2021-02-19T09:15:10.445Z  590.85  590.00   0.3
# 2  2021-02-19T09:15:11.400Z  590.85  590.00   0.3
# 3  2021-02-19T09:15:12.271Z  590.85  590.00   0.2
# 4  2021-02-19T09:15:13.083Z  590.85  589.25   0.0

# %%
##corelation in dataset v2

op_co_v2= data_v2.corr()
op_co_v2
# Out:
#            sid      high       low      perc
# sid   1.000000  0.439035 -0.859826 -0.919958
# high  0.439035  1.000000 -0.201520 -0.208189
# low  -0.859826 -0.201520  1.000000  0.915614
# perc -0.919958 -0.208189  0.915614  1.000000

# %%
##plot the graph 

#import required packages 
from pandas.plotting import scatter_matrix

scatter_matrix(data_v2,figsize=(16,12),alpha=0.3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002AE02AA1EE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AE03142310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AE0316E5E0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002AE0319AA30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AE031C7EB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AE031FF280>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002AE031FF370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AE0322B820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AE032850D0>]],
#       dtype=object)
